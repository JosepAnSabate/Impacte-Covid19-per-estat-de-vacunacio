# %%
import pandas as pd
import os
from datetime import datetime

# %% [markdown]
# [https://dadescovid.cat/documentacio](https://dadescovid.cat/documentacio)
#
# Aquestes dades provenen de diversos sistemes d'informació del Departament de Salut i del Servei Català de la Salut, detallats a https://dadescovid.cat/documentacio , i mostren, per a la data de referencia de cada registre, per sexe, per grup d'edat i per a tot Catalunya, des de l'inici de la campanya de vacunació, l'1 de gener de 2021, l'impacte del COVID-19 (nous casos, hospitalitzacions, hospitalitzacions en crítics i defuncions) segons l'estat de vacunació de les persones afectades.
#
# Cal tenir en compte que una mateixa persona està comptada tantes vegades com esdeveniments pels quals hagi passat.
#
# ### Cal tenir en compte que una mateixa persona està comptada tantes vegades com esdeveniments pels quals hagi passat.
#
# ### Usem els casos COVID-19 confirmats per PCR/TAR per al seguiment epidemiològic
# Primer de tot, els casos de COVID-19 confirmats per fer un seguiment epidemiològic són exclusivament els confirmats per PCR/TAR, ja que la PCR/TAR+ ens indica que és un cas actiu i pel seguiment epidemiològic és important la data en què s’inicia el cas.
#
# ### Hem de diferenciar el seguiment segons si la població és general o de residència
# I en tercer lloc és important diferenciar dues poblacions, la general i la de residències, ja que el seu comportament epidemiològic és totalment diferent, com es va poder veure en la primera onada. Per una banda, la població general viu en la comunitat i es relaciona i mou d’una determinada manera; les persones ingressades en residències geriàtriques, viuen en comunitats molt tancades i en llocs molt tancats i la seva mobilitat és molt reduïda. Donades aquestes característiques, no es pot fer el seguiment epidemiològic conjunt de les dues poblacions i és per això que a la web presentem les dades separades.

# %%
# handlig dates
dateparse = lambda x: datetime.strptime(x, '%d/%m/%Y')

# %%
filepath = 'C:/Users/34639/wa/impacte_covid_per_estat_vacunacio/dades/impacte_covid_vacunacio.csv'

# %%
df = pd.read_csv(filepath,parse_dates=['DATA'], date_parser=dateparse)
df.head(55)
# Out:
#     SEXE     EDAT       DATA     ESDEVENIMENT        PAUTA  RECOMPTE
# 0   Dona    0 a 9 2022-01-12              Cas      Parcial       107
# 1   Dona    0 a 9 2022-01-12              Cas  No iniciada       784
# 2   Home    0 a 9 2022-01-12              Cas  No iniciada       865
# 3   Home    0 a 9 2022-01-12              Cas      Parcial       126
# 4   Home    0 a 9 2022-01-12  Hospitalització  No iniciada         2
# 5   Dona  10 a 19 2022-01-12              Cas      Parcial       145
# 6   Dona  10 a 19 2022-01-12              Cas  No iniciada       316
# 7   Dona  10 a 19 2022-01-12              Cas     Completa       907
# 8   Dona  10 a 19 2022-01-12          Crítics     Completa         1
# 9   Home  10 a 19 2022-01-12  Hospitalització     Completa         1
# 10  Home  10 a 19 2022-01-12              Cas  No iniciada       385
# 11  Home  10 a 19 2022-01-12              Cas      Parcial       124
# 12  Home  10 a 19 2022-01-12              Cas     Completa       822
# 13  Dona  20 a 29 2022-01-12              Cas  No iniciada       135
# 14  Dona  20 a 29 2022-01-12              Cas      Parcial        35
# 15  Dona  20 a 29 2022-01-12  Hospitalització  No iniciada         4
# 16  Dona  20 a 29 2022-01-12              Cas     Completa       995
# 17  Home  20 a 29 2022-01-12              Cas      Parcial        38
# 18  Home  20 a 29 2022-01-12  Hospitalització  No iniciada         1
# 19  Home  20 a 29 2022-01-12              Cas  No iniciada       175
# 20  Home  20 a 29 2022-01-12  Hospitalització     Completa         3
# 21  Home  20 a 29 2022-01-12          Crítics     Completa         1
# 22  Home  20 a 29 2022-01-12              Cas     Completa       767
# 23  Dona  30 a 39 2022-01-12              Cas     Completa      1292
# 24  Dona  30 a 39 2022-01-12              Cas      Parcial        42
# 25  Dona  30 a 39 2022-01-12  Hospitalització     Completa         8
# 26  Dona  30 a 39 2022-01-12  Hospitalització      Parcial         2
# 27  Dona  30 a 39 2022-01-12              Cas  No iniciada       199
# 28  Dona  30 a 39 2022-01-12  Hospitalització  No iniciada         3
# 29  Home  30 a 39 2022-01-12              Cas      Parcial        33
# 30  Home  30 a 39 2022-01-12  Hospitalització     Completa         2
# 31  Home  30 a 39 2022-01-12              Cas     Completa       998
# 32  Home  30 a 39 2022-01-12  Hospitalització  No iniciada         1
# 33  Home  30 a 39 2022-01-12              Cas  No iniciada       183
# 34  Dona  40 a 49 2022-01-12  Hospitalització     Completa         9
# 35  Dona  40 a 49 2022-01-12  Hospitalització  No iniciada         1
# 36  Dona  40 a 49 2022-01-12              Cas  No iniciada       175
# 37  Dona  40 a 49 2022-01-12              Cas      Parcial        37
# 38  Dona  40 a 49 2022-01-12              Cas     Completa      1684
# 39  Home  40 a 49 2022-01-12  Hospitalització     Completa         5
# 40  Home  40 a 49 2022-01-12              Cas      Parcial        23
# 41  Home  40 a 49 2022-01-12  Hospitalització  No iniciada         6
# 42  Home  40 a 49 2022-01-12              Cas     Completa      1420
# 43  Home  40 a 49 2022-01-12  Hospitalització      Parcial         2
# 44  Home  40 a 49 2022-01-12          Crítics     Completa         2
# 45  Home  40 a 49 2022-01-12              Cas  No iniciada       179
# 46  Dona  50 a 59 2022-01-12          Crítics     Completa         2
# 47  Dona  50 a 59 2022-01-12              Cas     Completa      1079
# 48  Dona  50 a 59 2022-01-12          Crítics  No iniciada         1
# 49  Dona  50 a 59 2022-01-12              Cas      Parcial        12
# 50  Dona  50 a 59 2022-01-12              Cas  No iniciada        86
# 51  Dona  50 a 59 2022-01-12  Hospitalització  No iniciada         2
# 52  Dona  50 a 59 2022-01-12  Hospitalització     Completa         7
# 53  Home  50 a 59 2022-01-12  Hospitalització  No iniciada         6
# 54  Home  50 a 59 2022-01-12              Cas  No iniciada        65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28783 entries, 0 to 28782
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SEXE          28783 non-null  object
#  1   EDAT          28783 non-null  object
#  2   DATA          28783 non-null  datetime64[ns]
#  3   ESDEVENIMENT  28783 non-null  object
#  4   PAUTA         28783 non-null  object
#  5   RECOMPTE      28783 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (28783, 6)

# %%
# sum homes and dones
